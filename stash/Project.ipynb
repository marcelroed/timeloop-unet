# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
from pathlib import Path

from loaders import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
OUR_DIR               = Path('our_configs')
SYSTEM_ARCH           = OUR_DIR / 'system_arch.yaml'
MAPPER                = OUR_DIR / 'mapper.yaml'
RELAXED_CONSTRAINTS   = OUR_DIR / 'relaxed_constraints.yaml'
SYSTEM_COMPONENTS_DIR = OUR_DIR / 'components'

ALEXNET_LAYER_1 = OUR_DIR / 'alexnet_layer1.yaml'

# %%
show_config(ALEXNET_LAYER_1)
# Out:
# problem:
#   instance:
#     C: 3
#     Hdilation: 1
#     Hstride: 4
#     M: 64
#     N: 1
#     P: 55
#     Q: 55
#     R: 11
#     S: 11
#     Wdilation: 1
#     Wstride: 4
#   shape:
#     coefficients:
#     - default: 1
#       name: Wstride
#     - default: 1
#       name: Hstride
#     - default: 1
#       name: Wdilation
#     - default: 1
#       name: Hdilation
#     data-spaces:
#     - name: Weights
#       projection:
#       - - - C
#       - - - M
#       - - - R
#       - - - S
#     - name: Inputs
#       projection:
#       - - - N
#       - - - C
#       - - - R
#           - Wdilation
#         - - P
#           - Wstride
#       - - - S
#           - Hdilation
#         - - Q
#           - Hstride
#     - name: Outputs
#       projection:
#       - - - N
#       - - - M
#       - - - Q
#       - - - P
#       read-write: true
#     dimensions:
#     - C
#     - M
#     - R
#     - S
#     - N
#     - P
#     - Q
#     name: conv_layer

# %%
mapper_stats, mapper_loops = run_timeloop_mapper(
    SYSTEM_ARCH,
    SYSTEM_COMPONENTS_DIR,
    ALEXNET_LAYER_1,
    RELAXED_CONSTRAINTS,
    MAPPER
)
# Out:
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# ...
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 4
#   Factorization options along problem dimension M = 84
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
# ...

# %%
print(mapper_stats)
# Out:
# Buffer and Arithmetic Levels
# ----------------------------
# Level 0
# -------
# === mac ===
#
#     SPECS
#     -----
#     Word bits             : 16
#     Instances             : 10496 (82*128)
#     Compute energy        : 1.00 pJ
#
#     STATS
#     -----
#     Utilized instances      : 192
#     Computes (total)        : 70276800
#     Cycles                  : 366025
#     Energy (total)          : 70276800.00 pJ
#     Area (total)            : 10496.00 um^2
#
# Level 1
# -------
# === output_activation_reg ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 1
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 10496 (82*128)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
# ...

# %%
print(mapper_loops)
# Out:
# DRAM [ Weights:23232 (23232) Inputs:154587 (154587) Outputs:193600 (193600) ]
# -----------------------------------------------------------------------------
# | for Q in [0:1)
#
# global_buffer [ Weights:23232 (23232) Inputs:154587 (154587) Outputs:193600 (193600) ]
# --------------------------------------------------------------------------------------
# |   for Q in [0:1)
# |     for M in [0:64) (Spatial-Y)
# |       for C in [0:3) (Spatial-X)
#
# scratchpad [ Weights:121 (121) ]
# --------------------------------
# |         for R in [0:11)
# |           for S in [0:11)
# |             for P in [0:55)
# |               for Q in [0:55)
#
# weights_reg [ Weights:1 (1) ]
# -----------------------------
# |                 for Q in [0:1)
#
# input_activation_reg [ Inputs:1 (1) ]
# -------------------------------------
# |                   for Q in [0:1)
#
# output_activation_reg [ Outputs:1 (1) ]
# ---------------------------------------
# |                     for Q in [0:1)
